# %%
import numpy as np
big_list =[1,]
a_0 = 1

for i in range(1, 10000):
    a_1 = np.sqrt(3 + a_0)
    big_list.append(a_1)
    a_0 = a_1

# %%
big_list
# Out:
# [1,
#  2.0,
#  2.23606797749979,
#  2.288245611270737,
#  2.299618579519381,
#  2.302090045919008,
#  2.3026267708682204,
#  2.3027433141512366,
#  2.3027686193257098,
#  2.3027741138300364,
#  2.302775306848247,
#  2.302775565887446,
#  2.30277562213244,
#  2.302775634344875,
#  2.302775636996552,
#  2.3027756375723083,
#  2.302775637697322,
#  2.302775637724466,
#  2.30277563773036,
#  2.3027756377316395,
#  2.3027756377319175,
#  2.302775637731978,
#  2.3027756377319912,
#  2.302775637731994,
#  2.3027756377319943,
#  2.3027756377319943,
#  2.3027756377319943,
#  2.3027756377319943,
#  2.3027756377319943,
#  2.3027756377319943,
#  2.3027756377319943,
#  2.3027756377319943,
#  2.3027756377319943,
#  2.3027756377319943,
#  2.3027756377319943,
#  2.3027756377319943,
#  2.3027756377319943,
#  2.3027756377319943,
#  2.3027756377319943,
#  2.3027756377319943,
#  2.3027756377319943,
#  2.3027756377319943,
#  2.3027756377319943,
#  2.3027756377319943,
#  2.3027756377319943,
# ...
