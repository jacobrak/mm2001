# %%
import numpy as np
big_list =[1,]
a_0 = 1

for i in range(1, 10000):
    a_1 = np.sqrt(3 *a_0)
    big_list.append(a_1)
    a_0 = a_1

# %%
big_list
# Out:
# [1,
#  1.7320508075688772,
#  2.2795070569547775,
#  2.615056628615207,
#  2.80092304175706,
#  2.8987530293681765,
#  2.9489420286103507,
#  2.9743614585034974,
#  2.9871532226369792,
#  2.993569719901465,
#  2.9967831352475933,
#  2.9983911362166844,
#  2.9991954602276345,
#  2.9995977031400236,
#  2.999798844826111,
#  2.9998994207270235,
#  2.9999497099419967,
#  2.9999748548656187,
#  2.9999874274064644,
#  2.9999937136966457,
#  2.999996856846676,
#  2.999998428422926,
#  2.99999921421136,
#  2.999999607105654,
#  2.9999998035528206,
#  2.9999999017764085,
#  2.9999999508882036,
#  2.999999975444102,
#  2.999999987722051,
#  2.999999993861026,
#  2.9999999969305127,
#  2.9999999984652566,
#  2.9999999992326285,
#  2.9999999996163145,
#  2.9999999998081575,
#  2.999999999904079,
#  2.9999999999520397,
#  2.9999999999760196,
#  2.99999999998801,
#  2.9999999999940052,
#  2.999999999997003,
#  2.999999999998501,
#  2.999999999999251,
#  2.9999999999996256,
#  2.999999999999813,
# ...
